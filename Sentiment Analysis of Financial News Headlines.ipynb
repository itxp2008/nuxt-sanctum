# %%
# Import libraries
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# NLTK VADER for sentiment analysis
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')

finwiz_url = 'https://finviz.com/quote.ashx?t='
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
news_tables = {}
tickers = ['ADBE', 'ACN', 'RIVN', 'FDX']

for ticker in tickers:
    url = finwiz_url + ticker
    req = Request(url=url,headers={'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:20.0) Gecko/20100101 Firefox/20.0'}) 
    response = urlopen(req)    
    # Read the contents of the file into 'html'
    html = BeautifulSoup(response)
    # Find 'news-table' in the Soup and load it into 'news_table'
    news_table = html.find(id='news-table')
    # Add the table to our dictionary
    news_tables[ticker] = news_table

# %%
# Read one single day of headlines for 'AMZN' 
amzn = news_tables['ADBE']
# Get all the table rows tagged in HTML with <tr> into 'amzn_tr'
amzn_tr = amzn.findAll('tr')

for i, table_row in enumerate(amzn_tr):
    # Read the text of the element 'a' into 'link_text'
    a_text = table_row.a.text
    # Read the text of the element 'td' into 'data_text'
    td_text = table_row.td.text
    # Print the contents of 'link_text' and 'data_text' 
    print(a_text)
    print(td_text)
    # Exit after printing 4 rows of data
    if i == 3:
        break
# Out:
# Adobe Tumbles After Full-Year Revenue Forecast Trails Estimates
# Dec-16-21 09:22AM
# Dow Jones Futures Rise, With AMD, Nvidia Up; Adobe Dives On Guidance, Tesla Rival Rivian Earnings Loom
# 09:18AM
# Adobe Stock Sinks as Fiscal 2022 Forecast Falls Short of Estimates
# 09:01AM
# Adobe shares slammed premarket as guidance lags estimates
# 08:22AM

# %%
parsed_news = []

# Iterate through the news
for file_name, news_table in news_tables.items():
    # Iterate through all tr tags in 'news_table'
    for x in news_table.findAll('tr'):
        # read the text from each tr tag into text
        # get text from a only
        text = x.a.get_text() 
        # splite text in the td tag into a list 
        date_scrape = x.td.text.split()
        # if the length of 'date_scrape' is 1, load 'time' as the only element

        if len(date_scrape) == 1:
            time = date_scrape[0]
            
        # else load 'date' as the 1st element and 'time' as the second    
        else:
            date = date_scrape[0]
            time = date_scrape[1]
        # Extract the ticker from the file name, get the string up to the 1st '_'  
        ticker = file_name.split('_')[0]
        
        # Append ticker, date, time and headline as a list to the 'parsed_news' list
        parsed_news.append([ticker, date, time, text])
        
parsed_news
# Out:
# [['ADBE',
#   'Dec-16-21',
#   '09:22AM',
#   'Adobe Tumbles After Full-Year Revenue Forecast Trails Estimates'],
#  ['ADBE',
#   'Dec-16-21',
#   '09:18AM',
#   'Dow Jones Futures Rise, With AMD, Nvidia Up; Adobe Dives On Guidance, Tesla Rival Rivian Earnings Loom'],
#  ['ADBE',
#   'Dec-16-21',
#   '09:01AM',
#   'Adobe Stock Sinks as Fiscal 2022 Forecast Falls Short of Estimates'],
#  ['ADBE',
#   'Dec-16-21',
#   '08:22AM',
#   'Adobe shares slammed premarket as guidance lags estimates'],
#  ['ADBE',
#   'Dec-16-21',
#   '08:05AM',
#   'Adobe Reports Record Q4 and Fiscal 2021 Revenue; Company Outlines Strategy for Next Decade of Growth'],
#  ['ADBE',
#   'Dec-16-21',
#   '08:05AM',
#   'Adobe Announces Changes to Executive Leadership Team'],
#  ['ADBE',
#   'Dec-16-21',
#   '06:53AM',
#   'The Zacks Analyst Blog Highlights: Adobe, Raytheon, Anthem, Palo Alto Networks and Roper Tech'],
#  ['ADBE',
#   'Dec-16-21',
#   '06:20AM',
#   'Is Franklin LibertyQ U.S. Equity ETF (FLQL) a Strong ETF Right Now?'],
#  ['ADBE',
#   'Dec-16-21',
#   '03:40AM',
#   'Premarket Movers Thursday After Bank of England Rate Hike'],
#  ['ADBE',
#   'Dec-15-21',
#   '01:04PM',
#   'Retail Sales Werent as Bad as They Looked. Heres Why.'],
#  ['ADBE',
#   'Dec-15-21',
#   '12:33PM',
#   'Top Analyst Reports for Adobe, Raytheon & Anthem'],
#  ['ADBE', 'Dec-15-21', '11:26AM', 'Adobe Option Traders Betting Bearishly'],
#  ['ADBE',
#   'Dec-15-21',
#   '10:33AM',
#   'Adobe, Rivian, FedEx Earnings: 3 Things to Watch'],
#  ['ADBE', 'Dec-15-21', '09:37AM', 'Stock Market News for Dec 15, 2021'],
#  ['ADBE',
#   'Dec-15-21',
#   '09:17AM',
#   "Adobe's (ADBE) Creative Cloud Express to Expand Creator Base"],
#  ['ADBE',
#   'Dec-15-21',
#   '09:00AM',
#   'Adobe (NASDAQ:ADBE): A very Profitable Company now Trading at a Reasonable Price'],
#  ['ADBE',
#   'Dec-15-21',
#   '08:45AM',
#   'The Fed Selloff Is Easing, Lowes Is Slumpingand What Else Is Happening in the Stock Market Today'],
#  ['ADBE',
#   'Dec-15-21',
#   '07:24AM',
#   "Let's Check Adobe's Charts Ahead of Earnings"],
#  ['ADBE', 'Dec-15-21', '06:40AM', '3 Growth Stocks that Could Double in 2022'],
#  ['ADBE',
#   'Dec-15-21',
#   '06:20AM',
#   'Should Franklin LibertyQ U.S. Equity ETF (FLQL) Be on Your Investing Radar?'],
#  ['ADBE',
#   'Dec-15-21',
#   '01:38AM',
#   'VIP Balanced Portfolio Buys Alphabet Inc, Thermo Fisher Scientific Inc, Marsh & McLennan ...'],
#  ['ADBE',
#   'Dec-14-21',
#   '11:38PM',
#   'VanEck Morningstar Wide Moat ETF Buys Polaris Inc, The Western Union Co, KLA Corp, Sells Adobe ...'],
#  ['ADBE',
#   'Dec-14-21',
#   '09:38PM',
#   'VanEck Morningstar Global Wide Moat ETF Buys Wells Fargo, Safran SA, Boeing Co, Sells Adobe ...'],
#  ['ADBE',
#   'Dec-14-21',
#   '05:25PM',
#   'Dow Jones Falls; Tesla Stock Slips On Elon Musk Move; Senate Approves Debt Ceiling Hike'],
#  ['ADBE',
#   'Dec-14-21',
#   '04:15PM',
#   'Tech Stocks Fall On Red-Hot Inflation Report'],
#  ['ADBE',
#   'Dec-14-21',
#   '02:36PM',
#   'Apple stock dips, software stocks slump, AMC and GME remain volatile'],
#  ['ADBE', 'Dec-14-21', '01:29PM', 'Why Adobe Stock Fell Nearly 8% Today'],
#  ['ADBE',
#   'Dec-14-21',
#   '11:28AM',
#   "Will Digital Media Strength Aid Adobe's (ADBE) Q4 Earnings?"],
#  ['ADBE',
#   'Dec-14-21',
#   '11:20AM',
#   'Adobe and Other Software Stocks Are Diving. J.P. Morgan Made Harsh Calls.'],
#  ['ADBE',
#   'Dec-14-21',
#   '10:04AM',
#   'Adobe on Track to Beat Q4 Earnings After Noisy Q3 Results'],
#  ['ADBE',
#   'Dec-14-21',
#   '08:57AM',
#   '5 Top Stock Decliners for Tuesday Amid Market Selloff'],
#  ['ADBE',
#   'Dec-14-21',
#   '04:49AM',
#   'Wall Street Opens Mixed as PPI Reinforces Fed Concerns; Dow up 40 Pts'],
#  ['ADBE',
#   'Dec-13-21',
#   '08:02PM',
#   '2 Top Metaverse Stocks to Buy and Hold for the Next Decade'],
#  ['ADBE',
#   'Dec-13-21',
#   '04:38PM',
#   'Invesco V.I. Capital Appreciation Fund Buys Atlassian Corporation PLC, Apple Inc, Datadog Inc, ...'],
#  ['ADBE',
#   'Dec-13-21',
#   '11:50AM',
#   "Here's A Way To Profit From Adobe's Earnings Report With Options, But Risk Is Notable"],
#  ['ADBE',
#   'Dec-13-21',
#   '11:00AM',
#   'Adobe Targets Upstart Canva in Push for Video, Meme Creators'],
#  ['ADBE', 'Dec-13-21', '11:00AM', 'Adobe Introduces Creative Cloud Express'],
#  ['ADBE',
#   'Dec-13-21',
#   '09:46AM',
#   "Adobe (ADBE) to Post Q4 Earnings: What's in the Offing?"],
#  ['ADBE',
#   'Dec-13-21',
#   '09:39AM',
#   "Adobe Inc. -- Moody's announces completion of a periodic review of ratings of ADOBE INC."],
#  ['ADBE',
#   'Dec-13-21',
#   '06:33AM',
#   'FedEx Stock: Will FDX Earnings Deliver the Goods?'],
#  ['ADBE',
#   'Dec-13-21',
#   '06:10AM',
#   'One chart explains why the stock market is back in rally mode'],
#  ['ADBE',
#   'Dec-12-21',
#   '07:00AM',
#   '3 Things to Watch in the Stock Market This Week'],
#  ['ADBE',
#   'Dec-10-21',
#   '03:28PM',
#   'The Funded: The chairman of the SEC is seeking tighter rules for SPACs'],
#  ['ADBE',
#   'Dec-10-21',
#   '01:38PM',
#   'Jackson Wealth Management, LLC Buys BlackRock Inc, Adobe Inc, Equifax Inc, Sells Lam Research ...'],
#  ['ADBE',
#   'Dec-10-21',
#   '10:48AM',
#   'Sprinklr CEO on becoming a major customer experience player like Salesforce, Adobe, and Microsoft'],
#  ['ADBE',
#   'Dec-10-21',
#   '10:18AM',
#   'Adobe (ADBE), Real Madrid Unite for Experience Cloud Services'],
#  ['ADBE',
#   'Dec-10-21',
#   '10:05AM',
#   'ETFs to Benefit From a Record Surge in Online Prices'],
#  ['ADBE',
#   'Dec-10-21',
#   '04:44AM',
#   'Oracle (ORCL) Beats Q2 Earnings and Revenue Estimates'],
#  ['ADBE',
#   'Dec-09-21',
#   '06:39PM',
#   'Adobe (ADBE) to Boost Creative Capabilities With ContentCal'],
#  ['ADBE',
#   'Dec-09-21',
#   '03:00PM',
#   "Adobe Systems (ADBE) Earnings Expected to Grow: What to Know Ahead of Next Week's Release"],
#  ['ADBE',
#   'Dec-09-21',
#   '11:47AM',
#   'Prices for almost everything online are surging: Adobe data'],
#  ['ADBE',
#   'Dec-09-21',
#   '10:01AM',
#   'Online Prices Hit Record Levels as Shortages Bite Holiday Shoppers'],
#  ['ADBE', 'Dec-09-21', '08:00AM', 'Adobe Report: Inflation Online\xa0Soars'],
#  ['ADBE',
#   'Dec-09-21',
#   '08:00AM',
#   'Adobe Digital Price Index: Online Inflation Hits Record High'],
#  ['ADBE',
#   'Dec-09-21',
#   '07:01AM',
#   'Online Consumer Prices Rose in November for 18th Straight Month: Adobe'],
#  ['ADBE', 'Dec-09-21', '05:56AM', 'Should You Buy DocuSign Stock on the Dip?'],
#  ['ADBE',
#   'Dec-08-21',
#   '05:45PM',
#   'Adobe Systems (ADBE) Outpaces Stock Market Gains: What You Should Know'],
#  ['ADBE',
#   'Dec-08-21',
#   '12:00PM',
#   'Adobe Nears Deal for Social Marketing Startup ContentCal'],
#  ['ADBE', 'Dec-08-21', '09:35AM', 'Stock Market News for Dec 8, 2021'],
#  ['ADBE',
#   'Dec-07-21',
#   '04:53PM',
#   'Why High-Growth Tech Stocks Like Datadog Rose Today'],
#  ['ADBE',
#   'Dec-06-21',
#   '04:38PM',
#   'Is Adobe Inc. (ADBE) Going to Burn These Hedge Funds?'],
#  ['ADBE',
#   'Dec-06-21',
#   '08:23AM',
#   'Dow Jones Futures Rise As Tesla Leads Techs Lower In Grizzly Market; Lucid Dives On SEC Probe'],
#  ['ADBE',
#   'Dec-03-21',
#   '07:20PM',
#   'Adobe worth $26 billion less as DocuSign fears spark knee-jerk reaction for stock'],
#  ['ADBE',
#   'Dec-03-21',
#   '01:36PM',
#   'Peak issues for supply chains create portfolio opportunities: Chief market strategist'],
#  ['ADBE',
#   'Dec-03-21',
#   '07:15AM',
#   'Which E-Signature Company Is the Better Buy?'],
#  ['ADBE',
#   'Dec-03-21',
#   '05:52AM',
#   'Global tax deal leaves billion-dollar loopholes, Reuters analysis finds'],
#  ['ADBE',
#   'Dec-01-21',
#   '05:45PM',
#   'Adobe Systems (ADBE) Dips More Than Broader Markets: What You Should Know'],
#  ['ADBE',
#   'Nov-30-21',
#   '09:16AM',
#   'Cyber Monday Misses Estimates on Short Supply, Weak Deals'],
#  ['ADBE',
#   'Nov-30-21',
#   '01:43AM',
#   'Twitters New CEO Joins Club of India-Born U.S. Tech Captains'],
#  ['ADBE',
#   'Nov-29-21',
#   '06:53PM',
#   'Adobe Hosts Financial Analyst Meeting; Webcast to Include Q4 & FY2021 Earnings'],
#  ['ADBE',
#   'Nov-29-21',
#   '06:23PM',
#   'Online sales fell on Black Friday but should bounce back on Cyber Monday, analysts say'],
#  ['ADBE',
#   'Nov-29-21',
#   '05:49PM',
#   'The News of Omicron is Dominating the Market: What to Do Now'],
#  ['ADBE',
#   'Nov-29-21',
#   '11:40AM',
#   'Why Amazon Is Rising Higher on Cyber Monday'],
#  ['ADBE',
#   'Nov-29-21',
#   '10:07AM',
#   'Cyber Monday poised to be the biggest online shopping day of the year, but may still fall short of last years total'],
#  ['ADBE',
#   'Nov-29-21',
#   '08:38AM',
#   '2 Unstoppable Stocks to Buy Now and Hold Forever'],
#  ['ADBE', 'Nov-29-21', '06:30AM', 'Is Autodesk Stock a Buy?'],
#  ['ADBE',
#   'Nov-28-21',
#   '06:00PM',
#   'Cyber Monday Kicks Off After Black Fridays Mixed Bag for Retailers'],
#  ['ADBE',
#   'Nov-27-21',
#   '06:11AM',
#   "Adobe's (NASDAQ:ADBE) five-year total shareholder returns outpace the underlying earnings growth"],
#  ['ADBE',
#   'Nov-26-21',
#   '10:59AM',
#   'Black Friday e-commerce sales expected to approach $9 billion even as the power of major shopping days falls'],
#  ['ADBE',
#   'Nov-24-21',
#   '01:17PM',
#   'These stores will stay open on Thanksgiving  but many others are closed. Heres a handy list.'],
#  ['ADBE',
#   'Nov-24-21',
#   '07:33AM',
#   'Top Tech Stock Picks of Amir Mokaris Emerson Point Capital'],
#  ['ADBE',
#   'Nov-23-21',
#   '05:45PM',
#   'Adobe Systems (ADBE) Stock Sinks As Market Gains: What You Should Know'],
#  ['ADBE',
#   'Nov-23-21',
#   '12:43PM',
#   '7 Top Tech Stocks to Buy Despite Recent Tapering Concerns'],
#  ['ADBE',
#   'Nov-23-21',
#   '09:00AM',
#   'Adobe and Major League Baseball Partner to Create Next Generation Fan Experiences'],
#  ['ADBE',
#   'Nov-22-21',
#   '05:11PM',
#   'The Sectors to Focus on As the Holiday Season Kicks Off'],
#  ['ADBE',
#   'Nov-22-21',
#   '11:10AM',
#   'Dow Jones Rallies As Biden Picks Powell For Fed Chief; Tesla Races Higher On Elon Musk Tweet'],
#  ['ADBE',
#   'Nov-22-21',
#   '06:58AM',
#   'Adobe Upgraded to Overweight by Atlantic on Fundamentals'],
#  ['ADBE',
#   'Nov-22-21',
#   '06:17AM',
#   'Dev Kantesarias Stock Portfolio: Top 9 Stocks'],
#  ['ADBE',
#   'Nov-21-21',
#   '02:58PM',
#   'Amit Nitin Doshis Harbor Spring Capital Portfolio: Top 10 Stock Picks'],
#  ['ADBE',
#   'Nov-20-21',
#   '09:13AM',
#   '10 Best Growth Stocks to Buy Today According to Billionaire Ken Fisher'],
#  ['ADBE',
#   'Nov-19-21',
#   '09:30AM',
#   'New to Investing? This 1 Computer and Technology Stock Could Be the Perfect Starting Point'],
#  ['ADBE',
#   'Nov-19-21',
#   '08:40AM',
#   'Data Center Growth Is Still the Top Reason to Buy Nvidia Stock Now'],
#  ['ADBE',
#   'Nov-18-21',
#   '12:10PM',
#   'Artificial Intelligence Stocks To Buy And Watch Span Chips, Software, Internet Plays'],
#  ['ADBE',
#   'Nov-18-21',
#   '09:00AM',
#   'Adobe Taps Bolt to Integrate One-click Checkout With Commerce\xa0Platform'],
#  ['ADBE',
#   'Nov-18-21',
#   '08:39AM',
#   'Adobe taps startup Bolt to add one-click checkouts to commerce sites'],
#  ['ADBE',
#   'Nov-18-21',
#   '08:30AM',
#   'Adobe taps startup Bolt to add one-click checkouts to commerce sites'],
#  ['ADBE',
#   'Nov-17-21',
#   '12:04PM',
#   'The Zacks Analyst Blog Highlights: Adobe, Novo Nordisk, Qualcomm, Boeing, and Uber'],
#  ['ADBE',
#   'Nov-17-21',
#   '07:10AM',
#   'Will Adobe Be a Trillion-Dollar Company in 5 Years?'],
#  ['ADBE',
#   'Nov-16-21',
#   '04:07PM',
#   'Top Research Reports for Adobe, Novo Nordisk & Qualcomm'],
#  ['ADBE', 'Nov-16-21', '09:58AM', 'Big Money Has Designs on Adobe'],
#  ['ACN',
#   'Dec-16-21',
#   '09:21AM',
#   'Accenture Acquires Zestgroup to Help Clients Procure a More Sustainable Future'],
#  ['ACN',
#   'Dec-16-21',
#   '09:18AM',
#   'Dow Jones Futures Rise, With AMD, Nvidia Up; Adobe Dives On Guidance, Tesla Rival Rivian Earnings Loom'],
#  ['ACN',
#   'Dec-16-21',
#   '09:15AM',
#   "Thursday's Premarket Movers Tell a Tale of 2 Economies"],
#  ['ACN',
#   'Dec-16-21',
#   '08:38AM',
#   'Accenture Stock Is Surging Because the Company Is Feeling Even Better About 2022'],
#  ['ACN',
#   'Dec-16-21',
#   '07:56AM',
#   'Accenture Boosts Fiscal 2022 Guidance. The Stock Is Rising Sharply.'],
#  ['ACN',
#   'Dec-16-21',
#   '07:23AM',
#   'Accenture Stock Jumps On Strong Earnings, Full-Year Guidance'],
#  ['ACN',
#   'Dec-16-21',
#   '07:09AM',
#   'Accenture shares jump premarket after earnings beat estimates, company raises guidance'],
#  ['ACN',
#   'Dec-16-21',
#   '06:57AM',
#   'UPDATE 1-Accenture revenue forecast tops estimates on cloud, security services demand'],
#  ['ACN',
#   'Dec-16-21',
#   '06:56AM',
#   'Accenture revenue forecast tops estimates on cloud, security services demand'],
#  ['ACN',
#   'Dec-16-21',
#   '06:44AM',
#   'Accenture Reports Very Strong First-Quarter Results and Raises Business Outlook for Fiscal 2022'],
#  ['ACN',
#   'Dec-16-21',
#   '06:39AM',
#   'Accenture Launches 360° Value Reporting Experience'],
#  ['ACN',
#   'Dec-16-21',
#   '05:29AM',
#   'Accenture Named Leader for B2B Commerce and Digital Sales in Industrial Manufacturing by Analyst Firm IDC'],
#  ['ACN',
#   'Dec-16-21',
#   '03:40AM',
#   'Premarket Movers Thursday After Bank of England Rate Hike'],
#  ['ACN',
#   'Dec-15-21',
#   '06:59AM',
#   'Accenture to Host Conference Call Tomorrow, Dec. 16, to Discuss\xa0First-Quarter Fiscal Year 2022 Results'],
#  ['ACN',
#   'Dec-15-21',
#   '06:40AM',
#   'Accenture Announces Intent to Acquire AFD.TECH to Bolster its Cloud First Network Capabilities'],
#  ['ACN',
#   'Dec-15-21',
#   '02:38AM',
#   'Large Company Value Portfolio Buys Fresenius Medical Care AG. ...'],
#  ['ACN',
#   'Dec-14-21',
#   '03:16PM',
#   "Stocks To Buy And Watch Include Two Global Leaders On IBD's Stock Screener"],
#  ['ACN',
#   'Dec-14-21',
#   '11:02AM',
#   "What's in the Cards for Accenture (ACN) in Q1 Earnings?"],
#  ['ACN',
#   'Dec-14-21',
#   '09:00AM',
#   "Businesses Must Rethink Growth Strategies as People Examine Relationships with Work, Technology, Brands and the Planet, Finds Accenture's Annual Fjord Trends Report"],
#  ['ACN',
#   'Dec-14-21',
#   '07:59AM',
#   'Accenture Named a Leader in Data Management Service Providers: Q4, 2021 Report by Independent Research Firm'],
#  ['ACN',
#   'Dec-14-21',
#   '07:59AM',
#   'Accenture Helps Disney Studios StudioLAB Provide Fans with Immersive Experiences Through Interactive Movie Posters'],
#  ['ACN',
#   'Dec-13-21',
#   '06:38PM',
#   'ON BlackRock Advantage Large Cap Value Portfolio Buys Procter & Gamble Co, Life Storage ...'],
#  ['ACN',
#   'Dec-13-21',
#   '05:38PM',
#   'Ohio National Fund Inc Buys Procter & Gamble Co, Booking Holdings Inc, NVIDIA Corp, Sells ...'],
#  ['ACN',
#   'Dec-13-21',
#   '11:26AM',
#   'Accenture Scales to New Record High Ahead of Q1 Earnings; Target Price $410 in Best Case'],
#  ['ACN',
#   'Dec-09-21',
#   '04:46PM',
#   "Accenture plc -- Moody's announces completion of a periodic review of ratings of Accenture plc"],
#  ['ACN',
#   'Dec-09-21',
#   '03:00PM',
#   'Accenture (ACN) Earnings Expected to Grow: Should You Buy?'],
#  ['ACN',
#   'Dec-09-21',
#   '07:34AM',
#   'Generali launches corporate cyber insurance services'],
#  ['ACN',
#   'Dec-09-21',
#   '05:30AM',
#   'After Covid Closures, a New Quest to Make Offices Less Awful'],
#  ['ACN',
#   'Dec-08-21',
#   '06:00PM',
#   'Accenture (ACN) Outpaces Stock Market Gains: What You Should Know'],
#  ['ACN',
#   'Dec-08-21',
#   '11:40AM',
#   'III or ACN: Which Is the Better Value Stock Right Now?'],
#  ['ACN',
#   'Dec-08-21',
#   '08:00AM',
#   'Accenture and UiPath Join Forces to Help Organizations Accelerate Transformation through Intelligent Automation'],
#  ['ACN',
#   'Dec-07-21',
#   '03:36PM',
#   'Accenture Federal Services Launches St. Louis Apprenticeship Program'],
#  ['ACN',
#   'Dec-07-21',
#   '03:17PM',
#   'Hedge Funds Have Never Been This Bullish On Accenture Plc (ACN)'],
#  ['ACN',
#   'Dec-07-21',
#   '11:21AM',
#   'Accenture Federal Services, with plans to hire 1,400 tech empoyees in St. Louis, launches apprenticeship program'],
#  ['ACN',
#   'Dec-07-21',
#   '07:30AM',
#   'FourKites and Accenture Launch Global Supply Chain Research for Pharmaceutical Industry'],
#  ['ACN',
#   'Dec-07-21',
#   '06:59AM',
#   'Efma and Accenture Launch 7th Annual Innovation in Insurance Awards'],
#  ['ACN',
#   'Dec-06-21',
#   '07:59AM',
#   'Accenture Invests in Operational Resilience and Supply Chain Cybersecurity Company Interos'],
#  ['ACN',
#   'Dec-06-21',
#   '12:30AM',
#   'WWD Voices Podcast: Retails Responsible Reset\xa0Series'],
#  ['ACN',
#   'Dec-04-21',
#   '06:00AM',
#   'Accenture (NYSE:ACN) Might Be Having Difficulty Using Its Capital Effectively'],
#  ['ACN',
#   'Dec-02-21',
#   '10:45AM',
#   'Splunk (SPLK) Tops Estimates in Q3 Earnings, Revenues Up Y/Y'],
#  ['ACN',
#   'Dec-02-21',
#   '09:06AM',
#   'M&A wrap: Accenture buys Headspring; Go Pure Water Tech, Tango Health scooped up'],
#  ['ACN',
#   'Dec-02-21',
#   '08:26AM',
#   'Better Tech Dividend Stock: Oracle or Accenture'],
#  ['ACN',
#   'Dec-01-21',
#   '09:05AM',
#   'Accenture Acquires Headspring to Expand and Enhance Cloud First Platform Engineering Capabilities'],
#  ['ACN',
#   'Dec-01-21',
#   '07:40AM',
#   '2 Dividend-Paying High-Growth Tech Stocks to Buy'],
#  ['ACN',
#   'Dec-01-21',
#   '06:59AM',
#   'Accenture Promotes 1,030 New Managing Directors and Appoints 143 New Senior Managing Directors'],
#  ['ACN',
#   'Nov-30-21',
#   '08:11AM',
#   'The Zacks Analyst Blog Highlights: Accenture, Raytheon, Becton, Dickinson and Co, Boeing and Gilead Sciences'],
#  ['ACN',
#   'Nov-30-21',
#   '06:59AM',
#   'Accenture to Host Conference Call Thursday, Dec. 16, to Discuss\xa0First-Quarter Fiscal Year 2022 Results'],
#  ['ACN',
#   'Nov-29-21',
#   '07:31PM',
#   'Accenture Announces Extended Relationship with AWS and Joint Investments to Help Organizations Get to Cloud Value Faster'],
#  ['ACN',
#   'Nov-29-21',
#   '03:17PM',
#   'Top Analyst Reports for Accenture, Raytheon & Becton, Dickinson'],
#  ['ACN',
#   'Nov-29-21',
#   '01:11PM',
#   'Accenture to create 3,000 cybersecurity and technology jobs'],
#  ['ACN',
#   'Nov-25-21',
#   '07:00AM',
#   'In-Store and Last-Minute Holiday Shopping in Canada Making a Comeback, Accenture Survey Finds'],
#  ['ACN',
#   'Nov-24-21',
#   '11:08AM',
#   '10 Latest Stock Picks of Billionaire Ray Dalio'],
#  ['ACN', 'Nov-24-21', '10:14AM', 'Accenture Continues to Attract Big Money'],
#  ['ACN',
#   'Nov-23-21',
#   '06:23PM',
#   'Accenture (ACN) Stock Sinks As Market Gains: What You Should Know'],
#  ['ACN',
#   'Nov-23-21',
#   '09:51AM',
#   '7 Growth Stocks to Benefit From a Mark Mobius-Like India'],
#  ['ACN',
#   'Nov-22-21',
#   '11:40AM',
#   'III vs. ACN: Which Stock Is the Better Value Option?'],
#  ['ACN',
#   'Nov-22-21',
#   '11:33AM',
#   'Infosys (INFY) Upgrades South Florida Water Management to HANA'],
#  ['ACN',
#   'Nov-22-21',
#   '11:17AM',
#   "Accenture (ACN) to Gain From Tambourine Buyout: Here's How"],
#  ['ACN',
#   'Nov-22-21',
#   '10:08AM',
#   "Here's Why Investors Should Retain Accenture (ACN) Stock Now"],
#  ['ACN',
#   'Nov-20-21',
#   '09:31AM',
#   'Billionaire George Soros Is Buying These 10 Stocks'],
#  ['ACN',
#   'Nov-19-21',
#   '11:30AM',
#   'Accenture Federal Services Honored For Its DEI Initiative'],
#  ['ACN',
#   'Nov-19-21',
#   '11:12AM',
#   'Is it a Smart Move to Invest in Accenture (ACN)?'],
#  ['ACN',
#   'Nov-18-21',
#   '08:14PM',
#   'Accenture to Acquire Tambourine to Strengthen its World-Class Commerce Transformation Capabilities in Japan'],
#  ['ACN',
#   'Nov-18-21',
#   '10:30AM',
#   '5G Fixed Wireless Access Could Serve Nearly Half of U.S. Rural Households with High-Speed Broadband, New Study Finds'],
#  ['ACN',
#   'Nov-18-21',
#   '10:14AM',
#   'Efma and Accenture Announce Winners of the 2021 Banking Innovation Awards'],
#  ['ACN',
#   'Nov-18-21',
#   '10:03AM',
#   "Join Accenture's Celebration for International Day of Persons with Disabilities"],
#  ['ACN',
#   'Nov-18-21',
#   '07:59AM',
#   'Accenture and Icertis Form Strategic Partnership to Help Companies Modernize Contract Management'],
#  ['ACN',
#   'Nov-17-21',
#   '01:59PM',
#   'Accenture and Organon Team Up to Drive Digital Transformation for Better Patient and Employee Experiences'],
#  ['ACN',
#   'Nov-16-21',
#   '04:30PM',
#   'State of Innovation: Bracing for transformation, retail industry looks to woo consumers of the future'],
#  ['ACN',
#   'Nov-16-21',
#   '02:30PM',
#   'Karen Pavlin Named North America Inclusion & Diversity Lead At Consulting Giant Accenture'],
#  ['ACN',
#   'Nov-16-21',
#   '09:36AM',
#   "Accenture (ACN) to Benefit From T.A. Cook Buyout: Here's How"],
#  ['ACN',
#   'Nov-16-21',
#   '08:15AM',
#   'Accenture Acquires Founders Intelligence to Help Corporate Executives Drive Growth from Innovation'],
#  ['ACN',
#   'Nov-15-21',
#   '10:19AM',
#   'Accenture Acquires T.A. Cook, Strengthening Asset Performance Management Capabilities for Clients in Capital-Intensive Industries'],
#  ['ACN',
#   'Nov-14-21',
#   '07:01PM',
#   'U.K. Businesses Gear Up to Raise Prices, Survey Finds'],
#  ['ACN',
#   'Nov-14-21',
#   '06:02AM',
#   'Is Accenture plc (NYSE:ACN) Expensive For A Reason? A Look At Its Intrinsic Value'],
#  ['ACN',
#   'Nov-12-21',
#   '07:00AM',
#   "Accenture named to 2022 list of Canada's Top 100 Employers for 12th consecutive year"],
#  ['ACN',
#   'Nov-11-21',
#   '11:21AM',
#   'Microsoft and Meta Announce Partnership for Work Apps'],
#  ['ACN',
#   'Nov-10-21',
#   '08:59AM',
#   'Accenture Federal Services Wins $618 million U.S. Marshals Service Task Order'],
#  ['ACN', 'Nov-09-21', '07:01PM', 'The OUTstanding Top 50 Allies 2021'],
#  ['ACN',
#   'Nov-09-21',
#   '07:01PM',
#   'The OUTstanding Top 100 Future Leaders 2021'],
#  ['ACN',
#   'Nov-09-21',
#   '10:30AM',
#   'BrightTower Advises Procurement Spend Management Firm ClearEdge Partners in Sale to Accenture'],
#  ['ACN',
#   'Nov-09-21',
#   '10:09AM',
#   'Accenture Acquires\xa0ClearEdge\xa0to Help Clients Better Manage Digital Transformation Spend'],
#  ['ACN',
#   'Nov-09-21',
#   '07:59AM',
#   'Accenture Invests in Geneyx to Expand the Use of Genetic Data for Targeted and Personalized Therapeutics and Diagnostics'],
#  ['ACN',
#   'Nov-09-21',
#   '05:30AM',
#   'Accentures Julie Sweet: A.I. can transform companies, creating responsibility and possibility for CEOs'],
#  ['ACN',
#   'Nov-09-21',
#   '12:01AM',
#   'Banks Could Increase Annual Revenues by Nearly 4% by Embracing Innovative Business Models of Digital-Only Players, Accenture Report Finds'],
#  ['ACN',
#   'Nov-08-21',
#   '05:50PM',
#   'Accenture (ACN) Stock Sinks As Market Gains: What You Should Know'],
#  ['ACN',
#   'Nov-08-21',
#   '02:29PM',
#   'Was The Smart Money Right About Accenture Plc (ACN)?'],
#  ['ACN',
#   'Nov-05-21',
#   '11:40AM',
#   'NVEE vs. ACN: Which Stock Is the Better Value Option?'],
#  ['ACN',
#   'Nov-04-21',
#   '11:50AM',
#   'Accenture Federal Services Wins 2021 Government Contractor of the Year in the Over $300 Million Category'],
#  ['ACN',
#   'Nov-04-21',
#   '11:31AM',
#   'IBM spinoff Kyndryl begins trading: We have now complete freedom of action, CEO says'],
#  ['ACN',
#   'Nov-03-21',
#   '12:53PM',
#   'Microsoft (MSFT) Integrates Metaverse Into Its Software'],
#  ['ACN',
#   'Nov-03-21',
#   '05:59AM',
#   'More than Half of Organizations Not Effectively Defending Against Cyberattacks, According to Accenture Study'],
#  ['ACN',
#   'Nov-02-21',
#   '05:50PM',
#   'Accenture (ACN) Outpaces Stock Market Gains: What You Should Know'],
#  ['ACN',
#   'Nov-02-21',
#   '11:00AM',
#   'Microsofts Own Metaverse Is Coming, and It Will Have PowerPoint'],
#  ['ACN',
#   'Nov-01-21',
#   '07:59AM',
#   'Accenture Positioned as a Leader in IDC MarketScape: Worldwide Life Sciences Research & Development Vendor Assessment on IT Outsourcing for Fourth Consecutive Report'],
#  ['ACN',
#   'Oct-31-21',
#   '08:59PM',
#   'CEOs Unequivocally Call for Bold Government Action and Consistent Climate Policy at COP26, According to Latest Sustainability Research from the UN Global Compact and Accenture'],
#  ['ACN',
#   'Oct-27-21',
#   '06:34PM',
#   'Stocks To Buy And Watch Include This Chipmaker And A Stable, Cloud-Based Services Stock'],
#  ['ACN',
#   'Oct-27-21',
#   '05:50PM',
#   'Accenture (ACN) Dips More Than Broader Markets: What You Should Know'],
#  ['ACN',
#   'Oct-27-21',
#   '02:44PM',
#   'Stellantis, TIM and Accenture Collaborate on 5G Industrial Application in Brazil'],
#  ['ACN', 'Oct-27-21', '06:25AM', '5 Stocks Insiders Are Selling'],
#  ['RIVN',
#   'Dec-16-21',
#   '09:18AM',
#   'Dow Jones Futures Rise, With AMD, Nvidia Up; Adobe Dives On Guidance, Tesla Rival Rivian Earnings Loom'],
#  ['RIVN',
#   'Dec-16-21',
#   '07:30AM',
#   "Here's What 2 Investors Think of Rivian and Its Stock"],
#  ['RIVN',
#   'Dec-15-21',
#   '04:04PM',
#   'Rivian Stock: Analysts Bullish Ahead Of Post-IPO Earnings Report'],
#  ['RIVN',
#   'Dec-15-21',
#   '11:13AM',
#   'Rivian to Build $5bn Battery and Assembly Plant, AP Reports'],
#  ['RIVN',
#   'Dec-15-21',
#   '11:10AM',
#   'Rivian Picks Up an EV Award From Edmunds. Its Stock Falls Anyway.'],
#  ['RIVN',
#   'Dec-15-21',
#   '10:33AM',
#   'Adobe, Rivian, FedEx Earnings: 3 Things to Watch'],
#  ['RIVN',
#   'Dec-15-21',
#   '09:57AM',
#   'Dow Jones Falls Ahead Of Fed Decision; Tesla, EV Leaders Post Early Losses'],
#  ['RIVN',
#   'Dec-15-21',
#   '06:10AM',
#   'Love Rivian Automotive? This Hot Tech Stock Could Be Just for You'],
#  ['RIVN',
#   'Dec-14-21',
#   '04:25PM',
#   'Tesla Stock, IBD Stock Of The Day, Breaks Key Support Levels Amid Market Sell-Off, Elon Musk Sales'],
#  ['RIVN', 'Dec-14-21', '12:58PM', 'Why Rivian Stock Dropped Today'],
#  ['RIVN',
#   'Dec-14-21',
#   '11:51AM',
#   'Tesla to accept dogecoin for some merch sales, Elon Musk sells more company stock'],
#  ['RIVN',
#   'Dec-14-21',
#   '11:02AM',
#   'XPeng president details electric vehicle innovation, autonomous driving, and the EV market in China'],
#  ['RIVN',
#   'Dec-14-21',
#   '09:48AM',
#   'Dow Jones Reverses On Hot Inflation Report; Fed Meeting Looms; Tesla Skids As Musk Sells More Shares'],
#  ['RIVN',
#   'Dec-14-21',
#   '09:01AM',
#   'The Fed Meeting Could Be D-Day for Bitcoin and Other Cryptos'],
#  ['RIVN',
#   'Dec-14-21',
#   '08:07AM',
#   'Dow Jones Futures Rise After Stock Market Sells Off Ahead Of Fed Meeting; Elon Musk Sells More Tesla Stock'],
#  ['RIVN',
#   'Dec-14-21',
#   '08:03AM',
#   'Is Rivian Automotive (RIVN) A Smart Investment Choice?'],
#  ['RIVN',
#   'Dec-13-21',
#   '04:07PM',
#   'Rivian Stock: R1T Pickup Named 2022 MotorTrend Truck Of The Year'],
#  ['RIVN',
#   'Dec-13-21',
#   '03:13PM',
#   'Lucid Group stock rallies after Nasdaq Tech 100 inclusion'],
#  ['RIVN', 'Dec-13-21', '12:50PM', 'Why Rivian Stock Is Electric Today'],
#  ['RIVN',
#   'Dec-13-21',
#   '12:25PM',
#   'Dow Jones Loses 350 Points As Fed Meeting Looms; EV Stocks Skid, But Covid Stocks Rally'],
#  ['RIVN',
#   'Dec-13-21',
#   '11:44AM',
#   'Elon Musk on electric vehicle competition: Im confident in the future of Tesla'],
#  ['RIVN',
#   'Dec-13-21',
#   '10:33AM',
#   'Stock Market Starts Week Lower As Apple Nears This Major Milestone; Pfizer Makes $6.7 Bil Deal'],
#  ['RIVN',
#   'Dec-13-21',
#   '10:27AM',
#   'Rivians R1T Named Truck of the Year. The Stock Is Up.'],
#  ['RIVN',
#   'Dec-13-21',
#   '10:03AM',
#   "Dow Jones Falls As Apple Hits New Highs; Tesla Skids, Rivian Called 'Most Remarkable' Truck Of The Year"],
#  ['RIVN',
#   'Dec-13-21',
#   '10:01AM',
#   'Lucid and Rivian Are Soaring Again. Which EV Stock Is The Better Buy?'],
#  ['RIVN',
#   'Dec-13-21',
#   '09:52AM',
#   "Rivian stock rises after the electric automaker wins MotorTrend's truck of the year award"],
#  ['RIVN',
#   'Dec-13-21',
#   '09:10AM',
#   'Rivian nabs a coveted MotorTrend award for its debut EV pickup, putting pressure on Tesla'],
#  ['RIVN',
#   'Dec-13-21',
#   '08:28AM',
#   'Rivians R1T Is MotorTrends 2022 Truck of the Year. The Stock Is Up.'],
#  ['RIVN',
#   'Dec-13-21',
#   '08:21AM',
#   'Dow Jones Futures Rise With Fed Set To Speed Up Inflation Fight; Apple, Tesla, Rivian In Focus'],
#  ['RIVN',
#   'Dec-13-21',
#   '01:52AM',
#   "Rivian R1T Crowned as MotorTrend's 2022 Truck of the Year"],
#  ['RIVN',
#   'Dec-12-21',
#   '08:09PM',
#   'Looking to Ride the Electric Vehicle Boom? These Analysts Suggest 2 EV Stocks to Buy'],
#  ['RIVN',
#   'Dec-12-21',
#   '03:00PM',
#   'FedEx, Rivian, Lennar, Campbell Soup, Adobe, and Other Stocks to Watch This Week'],
#  ['RIVN',
#   'Dec-11-21',
#   '12:00AM',
#   'The Challenging Road Ahead for Rivians Billionaire CEO'],
#  ['RIVN',
#   'Dec-10-21',
#   '07:45PM',
#   'Tesla Partnership and Less Debt Can Drive Hertz Stock Higher'],
#  ['RIVN',
#   'Dec-10-21',
#   '04:47PM',
#   'Amazon-Backed Rivian Set to Announce\xa0Plan for Georgia EV Factory'],
#  ['RIVN',
#   'Dec-10-21',
#   '09:59AM',
#   'Dow Jones Rallies After Hot Inflation Reading; Tesla Slides As Elon Musk Sells More Shares'],
#  ['RIVN', 'Dec-09-21', '10:30PM', '3 Investors Weigh In on the Rivian IPO'],
#  ['RIVN',
#   'Dec-09-21',
#   '01:53PM',
#   "This year's big IPOs  from EVs to sustainable footwear"],
#  ['RIVN',
#   'Dec-09-21',
#   '01:20PM',
#   'Electric vehicle stocks sagging amid mixed market day'],
#  ['RIVN',
#   'Dec-09-21',
#   '10:55AM',
#   'Behind the Wall: Fund Manager Says EV Stocks Will Ride Rising Tide'],
#  ['RIVN',
#   'Dec-09-21',
#   '10:31AM',
#   'Apple car unit loses key engineers to Joby, Archer air taxi upstarts'],
#  ['RIVN',
#   'Dec-09-21',
#   '10:20AM',
#   "Will Rivian's Sales Justify a $100 Billion Valuation?"],
#  ['RIVN',
#   'Dec-09-21',
#   '10:00AM',
#   'Once-Hot IPOs Stumble as Market Volatility Picks Up'],
#  ['RIVN',
#   'Dec-09-21',
#   '09:59AM',
#   'Dow Jones Drops As Jobless Claims Fall To 52-Year Low; Apple Hits More Highs; Lucid Motors Dives On Debt Offering'],
#  ['RIVN',
#   'Dec-09-21',
#   '08:11AM',
#   "4 Stocks in Focus on Biden's Bold Electric Fleet Targets"],
#  ['RIVN',
#   'Dec-09-21',
#   '02:45AM',
#   "Electric Vehicle Checkpoint: Tesla CEO Elon Musk Knocks Biden's EV Bill"],
#  ['RIVN',
#   'Dec-08-21',
#   '05:49PM',
#   'Apples Car Project Loses Three More Key Engineers to Startups'],
#  ['RIVN',
#   'Dec-08-21',
#   '04:36PM',
#   'Tesla CEO Elon Musk teases Cybertruck, Ford boasts 200,000 preorders for electric F-150 Lightning'],
#  ['RIVN',
#   'Dec-08-21',
#   '11:29AM',
#   'Rivian is the one that can challenge Tesla: Morgan Stanley'],
#  ['RIVN',
#   'Dec-08-21',
#   '11:03AM',
#   'BofA Explains Neutral Rating for Tesla, Buy for Rivian, Lucid'],
#  ['RIVN',
#   'Dec-08-21',
#   '09:48AM',
#   'Dow Jones Rallies On Pfizer Vaccine News; Apple Hits New High, Tesla Falls Despite Strong China Sales'],
#  ['RIVN',
#   'Dec-08-21',
#   '07:10AM',
#   'Should Investors Worry About the Gender Discrimination Lawsuit Recently Filed Against Rivian?'],
#  ['RIVN',
#   'Dec-08-21',
#   '06:38AM',
#   "If You Like Rivian, You'll Love These 2 Stocks"],
#  ['RIVN',
#   'Dec-07-21',
#   '03:57PM',
#   'Rivian Stocks Estimates Are All Over the Place, Even for Bulls'],
#  ['RIVN',
#   'Dec-07-21',
#   '11:30AM',
#   'Rivian Estimates Are All Over the Place, Even for Bulls. How Wall Street Works.'],
#  ['RIVN',
#   'Dec-07-21',
#   '09:48AM',
#   'Dow Jones Surges As Intel Jumps On Mobileye Plans; Apple, Tesla Set To Rally'],
#  ['RIVN',
#   'Dec-07-21',
#   '09:47AM',
#   "What Ford's November Sales Reveal About Its Turnaround Efforts"],
#  ['RIVN',
#   'Dec-07-21',
#   '09:28AM',
#   'Tesla CEO Elon Musk speaks out against Bidens EV tax credits'],
#  ['RIVN',
#   'Dec-07-21',
#   '09:08AM',
#   "Amazon's (AMZN) AWS Gets Selected by Rivian, Boosts Clientele"],
#  ['RIVN',
#   'Dec-07-21',
#   '07:35AM',
#   'Dow Jones Futures Surge: Is Stock Market Correction Over? What To Do Now'],
#  ['RIVN', 'Dec-07-21', '05:55AM', 'Rivian: An EV Star Is Born'],
#  ['RIVN',
#   'Dec-06-21',
#   '05:57PM',
#   'Tesla Stock Dips, Lucid Motors Tumbles Amid SEC Probes; Rivian Jumps On Buy Ratings'],
#  ['RIVN',
#   'Dec-06-21',
#   '05:33PM',
#   'Why Rivian Stock Stomped on the Accelerator Today'],
#  ['RIVN',
#   'Dec-06-21',
#   '04:29PM',
#   'Rivian Sets Date for Release of Third Quarter 2021 Results'],
#  ['RIVN',
#   'Dec-06-21',
#   '03:13PM',
#   'Rivian: Production and delivery of EVs expected this quarter, analyst says'],
#  ['RIVN',
#   'Dec-06-21',
#   '01:37PM',
#   'Rivian Ratings Arrive. They Are More Positive Than Tesla.'],
#  ['RIVN',
#   'Dec-06-21',
#   '10:59AM',
#   'Ford could sell down Rivian stake to fuel its business, RBC says'],
#  ['RIVN',
#   'Dec-06-21',
#   '10:22AM',
#   'Rivian is the one that could disrupt Tesla, analysts say'],
#  ['RIVN',
#   'Dec-06-21',
#   '10:04AM',
#   'Rivian receives positive ratings in initial Wall Street coverage'],
#  ['RIVN', 'Dec-06-21', '09:55AM', 'Lucid shares drop following SEC subpoena'],
#  ['RIVN',
#   'Dec-06-21',
#   '09:40AM',
#   'Dow Jones Rallies, Tech Stocks Sell Off; Lucid Plunges 15% On SEC Probe; Tesla Falls To Key Support'],
#  ['RIVN',
#   'Dec-06-21',
#   '08:23AM',
#   'Dow Jones Futures Rise As Tesla Leads Techs Lower In Grizzly Market; Lucid Dives On SEC Probe'],
#  ['RIVN',
#   'Dec-06-21',
#   '07:51AM',
#   'Rivian Ratings Arrive. They Are More Positive Than Tesla.'],
#  ['RIVN',
#   'Dec-06-21',
#   '06:42AM',
#   'Bitcoin Is Still Falling. The Dip-Buyers Are Staying Away.'],
#  ['RIVN',
#   'Dec-06-21',
#   '06:18AM',
#   "Rivian is 'The One' To Challenge Tesla, Says Morgan Stanley"],
#  ['RIVN',
#   'Dec-06-21',
#   '05:35AM',
#   "Looking at 4 EV Stocks and Their Charts: Here's My Take"],
#  ['RIVN',
#   'Dec-06-21',
#   '05:17AM',
#   'EV Disruptor Rivian Lauded on Wall Street With Valuation Caution'],
#  ['RIVN',
#   'Dec-04-21',
#   '01:23PM',
#   'Rivian Stock Ratings Should Arrive This Week. What to Know.'],
#  ['RIVN', 'Dec-04-21', '10:00AM', "Here's My Top Stock to Buy in December"],
#  ['RIVN',
#   'Dec-03-21',
#   '04:08PM',
#   'Ford could become the second largest EV manufacturer globally: Analyst'],
#  ['RIVN',
#   'Dec-03-21',
#   '11:46AM',
#   'Boris Johnson woos Rivian in bid to bring £1bn electric vehicle factory to UK'],
#  ['RIVN',
#   'Dec-03-21',
#   '10:01AM',
#   'Dow Jones Reverses, Tech Stocks Sell Off After Weak Jobs Report; Tesla Falls As Elon Musk Sells More Shares'],
#  ['RIVN',
#   'Dec-03-21',
#   '08:05AM',
#   'Rivian Automotive Stock Will Have a Long Road Back to Its $180 Highs'],
#  ['RIVN', 'Dec-03-21', '08:03AM', 'Rivian: Is the Valuation Justifiable?'],
#  ['RIVN',
#   'Dec-03-21',
#   '07:30AM',
#   'Rivian Stock Could Reach $200 in Just a Few Months'],
#  ['RIVN',
#   'Dec-02-21',
#   '05:10PM',
#   'Dow Jones Futures: Market Rallies, But Be Wary; Tesla Rivals Lucid, Rivian, Xpeng, Li Auto Skid; DocuSign, Asana Dive With Jobs Report On Tap'],
#  ['RIVN',
#   'Dec-02-21',
#   '11:21AM',
#   'Why Investors Need to Stay Far Away From Rivian (for Now)'],
#  ['RIVN',
#   'Dec-02-21',
#   '09:56AM',
#   'GM shares advance, Boeing stock jumps, Dollar General stock dips'],
#  ['RIVN',
#   'Dec-02-21',
#   '09:54AM',
#   'Dow Jones Rallies, But Stock Market Sell-Off Worsens; Apple Slides On Weak iPhone Demand'],
#  ['RIVN',
#   'Dec-02-21',
#   '09:39AM',
#   'Rivian Stock Might Be Worth the Price. Electric Trucks Should Be Big Sellers.'],
#  ['RIVN',
#   'Dec-02-21',
#   '09:00AM',
#   'Rivian Selects AWS as Its Preferred Cloud Provider to Drive Efficiency, Performance, and Refinement of Electric Vehicles'],
#  ['RIVN', 'Dec-02-21', '08:22AM', 'Is Rivian Stock a Buy After the IPO?'],
#  ['RIVN',
#   'Dec-01-21',
#   '03:10PM',
#   'Wait for the EV Trend to Fizzle Out Before Buying Rivian'],
#  ['RIVN',
#   'Dec-01-21',
#   '03:04PM',
#   'Jay Leno: Tesla is probably 8-10 years ahead in battery technology compared to competitors'],
#  ['RIVN',
#   'Dec-01-21',
#   '10:14AM',
#   'Tesla competitors XPeng, NIO post strong delivery numbers'],
#  ['RIVN',
#   'Dec-01-21',
#   '09:45AM',
#   'Dow Jones Snaps Back From Stock Market Sell-Off; Apple Hits New High, Tesla Rivals Jump On Strong Deliveries'],
#  ['RIVN', 'Dec-01-21', '09:12AM', '2 EV Stocks I Would Buy Before Rivian'],
#  ['RIVN',
#   'Dec-01-21',
#   '09:01AM',
#   "Beyond Rivian: Buy These 2 Stocks Integral to Its Trucks' Design"],
#  ['RIVN', 'Dec-01-21', '07:44AM', 'Is Rivian Stock a Buy?'],
#  ['RIVN',
#   'Nov-30-21',
#   '02:11PM',
#   'EV Space is All Charged-Up With IPO News: ETFs to Play'],
#  ['FDX',
#   'Dec-16-21',
#   '09:18AM',
#   'Dow Jones Futures Rise, With AMD, Nvidia Up; Adobe Dives On Guidance, Tesla Rival Rivian Earnings Loom'],
#  ['FDX',
#   'Dec-16-21',
#   '08:38AM',
#   'FedEx Option Traders Cautious Before Earnings'],
#  ['FDX',
#   'Dec-16-21',
#   '06:00AM',
#   'FedEx Earnings On Tap After Delivery Giant Predicted A Bumper Holiday Season'],
#  ['FDX',
#   'Dec-15-21',
#   '08:38PM',
#   'Russell Investment Funds Buys Catalent Inc, Willis Towers Watson PLC, Edison International, ...'],
#  ['FDX',
#   'Dec-15-21',
#   '04:16PM',
#   'FedEx doubles size of cargo hub at MIA, intends to hire hundreds'],
#  ['FDX',
#   'Dec-15-21',
#   '02:13PM',
#   'FedEx Express completes $72.2M expansion in Miami'],
#  ['FDX',
#   'Dec-15-21',
#   '11:50AM',
#   'Aurora partners with Uber Freight for autonomous trucking pilot'],
#  ['FDX',
#   'Dec-15-21',
#   '10:33AM',
#   'Adobe, Rivian, FedEx Earnings: 3 Things to Watch'],
#  ['FDX',
#   'Dec-15-21',
#   '04:55AM',
#   "Don't Wait, Click Now, If You Want That Delivered By Christmas"],
#  ['FDX',
#   'Dec-14-21',
#   '04:38PM',
#   'Day Hagan Logix Smart Value Fund Buys Werner Enterprises Inc, Landstar System Inc, FedEx Corp, ...'],
#  ['FDX',
#   'Dec-14-21',
#   '03:58PM',
#   'Fedex Express Completes Expansion At Miami International Airport'],
#  ['FDX',
#   'Dec-14-21',
#   '03:00PM',
#   'FedEx Express Completes Major Expansion at Miami International Airport'],
#  ['FDX',
#   'Dec-14-21',
#   '02:53PM',
#   'FedEx Corp. adds CEO of major Texas firm to its board of directors'],
#  ['FDX',
#   'Dec-14-21',
#   '01:38PM',
#   'Strategy Asset Managers Llc Buys Broadcom Inc, eBay Inc, Extra Space Storage Inc, Sells , Meta ...'],
#  ['FDX',
#   'Dec-14-21',
#   '11:08AM',
#   "FedEx Fell Out of the Box, and Here's Where Traders Could Catch It"],
#  ['FDX',
#   'Dec-14-21',
#   '11:00AM',
#   'Boeing delivers 34 aircraft in November, picks up Southwest order'],
#  ['FDX',
#   'Dec-13-21',
#   '05:39PM',
#   "How is FedEx's (FDX) Ground Unit Likely to Fare in Q2 Earnings?"],
#  ['FDX',
#   'Dec-13-21',
#   '04:05PM',
#   'Fred Perpall, CEO of The Beck Group, Joins FedEx Corporation Board of Directors'],
#  ['FDX',
#   'Dec-13-21',
#   '11:41AM',
#   'FedEx Celebrates Its First African American Female Flight Crew'],
#  ['FDX',
#   'Dec-13-21',
#   '11:12AM',
#   'FedEx and Darden Restaurants are part of Zacks Earnings Preview'],
#  ['FDX',
#   'Dec-13-21',
#   '09:00AM',
#   'UPS, Postal Service Step Up On-Time Holiday Deliveries, Data Show'],
#  ['FDX',
#   'Dec-13-21',
#   '06:33AM',
#   'FedEx Stock: Will FDX Earnings Deliver the Goods?'],
#  ['FDX',
#   'Dec-12-21',
#   '03:00PM',
#   'FedEx, Rivian, Lennar, Campbell Soup, Adobe, and Other Stocks to Watch This Week'],
#  ['FDX',
#   'Dec-11-21',
#   '02:38AM',
#   'PGIM Jennison Focused Value Fund Buys Qualcomm Inc, Sells FedEx Corp, PTC Inc, Cigna Corp'],
#  ['FDX',
#   'Dec-11-21',
#   '01:38AM',
#   'Southeastern Asset Management Buys Discovery Inc, IAC/InterActiveCorp, RenaissanceRe Holdings, ...'],
#  ['FDX', 'Dec-10-21', '01:05PM', 'Q4 Earnings Season Gets Underway'],
#  ['FDX',
#   'Dec-10-21',
#   '01:04PM',
#   "FedEx (FDX) to Report Q2 Earnings: What's in the Offing?"],
#  ['FDX',
#   'Dec-10-21',
#   '04:41AM',
#   'Mesa Air (MESA) Reports Q4 Loss, Lags Revenue Estimates'],
#  ['FDX',
#   'Dec-10-21',
#   '01:38AM',
#   'Madison Covered Call & Equity Strategy Fund Buys PayPal Holdings Inc, T-Mobile US Inc, Visa ...'],
#  ['FDX',
#   'Dec-09-21',
#   '03:00PM',
#   'Analysts Estimate FedEx (FDX) to Report a Decline in Earnings: What to Look Out for'],
#  ['FDX',
#   'Dec-09-21',
#   '03:21AM',
#   'StealthGas (GASS) Q3 Earnings and Revenues Top Estimates'],
#  ['FDX',
#   'Dec-08-21',
#   '10:14PM',
#   'Hedge Funds Arent Crazy About FedEx Corporation (FDX) Anymore'],
#  ['FDX',
#   'Dec-08-21',
#   '02:55PM',
#   'Industrial real estate giant buys Triad property for $23.4 million'],
#  ['FDX',
#   'Dec-08-21',
#   '12:22PM',
#   "Supply Chain Struggles Won't Lead to Blue Christmas for Retailers. Here's Why."],
#  ['FDX',
#   'Dec-08-21',
#   '10:23AM',
#   'Is it Safe to Keep Your FedEx (FDX) Shares?'],
#  ['FDX',
#   'Dec-08-21',
#   '08:08AM',
#   'Supply chains: The Omicron variant is a key uncertainty going into 2022, economist says'],
#  ['FDX',
#   'Dec-07-21',
#   '12:23PM',
#   '2021 holiday shipping deadlines loom for FedEx, UPS, and USPS'],
#  ['FDX',
#   'Dec-06-21',
#   '05:45PM',
#   'FedEx (FDX) Outpaces Stock Market Gains: What You Should Know'],
#  ['FDX',
#   'Dec-06-21',
#   '04:20PM',
#   '2 Stocks for Longer-Term Investors to Buy Ahead of December Earnings'],
#  ['FDX',
#   'Dec-06-21',
#   '09:01AM',
#   'FedEx Q2 Earnings To Come In Below Consensus, Says Morgan Stanley'],
#  ['FDX',
#   'Dec-06-21',
#   '07:31AM',
#   'Womans email and photos compromised by hacker looking for nudes after she sent phone to Google for repair'],
#  ['FDX',
#   'Dec-06-21',
#   '05:51AM',
#   'FedEx Gains as it Forecasts a Bumper Holiday Season'],
#  ['FDX',
#   'Dec-05-21',
#   '07:30AM',
#   'Is It Time To Buy the 5 Worst-Performing Blue-Chip Stocks of 2021?'],
#  ['FDX',
#   'Dec-05-21',
#   '06:24AM',
#   'Be Sure To Check Out FedEx Corporation (NYSE:FDX) Before It Goes Ex-Dividend'],
#  ['FDX',
#   'Dec-03-21',
#   '01:15PM',
#   'Is FedEx Corporation (NYSE:FDX) Trading At A 29% Discount?'],
#  ['FDX',
#   'Dec-03-21',
#   '11:50AM',
#   'The Jack Dorsey News Got These Investors Talking'],
#  ['FDX', 'Dec-02-21', '12:38PM', 'How FedEx Could Get Back to $300'],
#  ['FDX', 'Dec-01-21', '09:02AM', 'Giving Is Better Than Receiving'],
#  ['FDX',
#   'Dec-01-21',
#   '06:23AM',
#   'Top 10 Stock Picks of Steve Zhengs Deepcurrents Investment Group'],
#  ['FDX',
#   'Nov-29-21',
#   '10:00PM',
#   "Amazon to Overtake UPS and FedEx as America's Largest Delivery Service"],
#  ['FDX',
#   'Nov-29-21',
#   '10:00PM',
#   'ByteDance Backs Dubai Startup Building Logistics Chain to China'],
#  ['FDX',
#   'Nov-29-21',
#   '05:45PM',
#   'FedEx (FDX) Gains But Lags Market: What You Should Know'],
#  ['FDX',
#   'Nov-29-21',
#   '11:20AM',
#   'Union Labor Helped UPS. Now It Could Hurt. What to Buy Instead.'],
#  ['FDX',
#   'Nov-29-21',
#   '09:50AM',
#   'Amazon Predicts It Will Pass UPS and Fedex as Biggest U.S. Shipper'],
#  ['FDX',
#   'Nov-27-21',
#   '10:44AM',
#   'U.S. shippers prepare for another pandemic crush of holiday gifts'],
#  ['FDX',
#   'Nov-26-21',
#   '02:28PM',
#   'Hundreds of FedEx packages found dumped in Alabama woods under investigation'],
#  ['FDX',
#   'Nov-26-21',
#   '11:55AM',
#   'On the Front Lines of the Supply-Chain Crisis'],
#  ['FDX',
#   'Nov-25-21',
#   '11:39AM',
#   'Spike in applications to blame for passport delays, FedEx says'],
#  ['FDX',
#   'Nov-24-21',
#   '03:22PM',
#   'Supply chain backlogs: You have seen the worst of it, Port of Long Beach executive director says'],
#  ['FDX',
#   'Nov-24-21',
#   '10:31AM',
#   '3 Stocks to Buy to Play Black Friday This Year'],
#  ['FDX',
#   'Nov-24-21',
#   '09:17AM',
#   '15 Stock Picks of Michael O Keefes 12th Street Asset Management'],
#  ['FDX',
#   'Nov-23-21',
#   '06:13PM',
#   'FedEx Freight and the Christmas SPIRIT Foundation Delivering Joy to Military Families This Holiday Season'],
#  ['FDX',
#   'Nov-23-21',
#   '05:45PM',
#   'FedEx (FDX) Stock Sinks As Market Gains: What You Should Know'],
#  ['FDX',
#   'Nov-23-21',
#   '05:33AM',
#   'UPS, FedEx Get a Head Start on Holiday Deliveries'],
#  ['FDX',
#   'Nov-22-21',
#   '02:56PM',
#   'Why these are the worst stocks to own right now: Goldman Sachs'],
#  ['FDX',
#   'Nov-22-21',
#   '01:31PM',
#   'Cigna CEO David Cordani and FedEx CEO Frederick W. Smith Join Together to Highlight the Unique Value Veterans Bring to the Workforce'],
#  ['FDX',
#   'Nov-19-21',
#   '12:56PM',
#   'FedEx (FDX) Expects 10% Uptick in Holiday Package Deliveries'],
#  ['FDX', 'Nov-19-21', '10:46AM', 'Avanzando Juntos / Growing Together'],
#  ['FDX',
#   'Nov-19-21',
#   '09:37AM',
#   'LendingClub, FedEx, Applied Materials and Williams-Sonoma highlighted as Zacks Bull and Bear of the Day'],
#  ['FDX',
#   'Nov-19-21',
#   '09:00AM',
#   'FedEx Corp. Board Declares Quarterly Dividend'],
#  ['FDX',
#   'Nov-19-21',
#   '07:24AM',
#   'Cargo Pilots Leave Hong Kong, as Covid Rules Collide With Supply Chains'],
#  ['FDX', 'Nov-19-21', '05:00AM', 'Bear of the Day: FedEx (FDX)'],
#  ['FDX', 'Nov-18-21', '06:51PM', 'FedEx plans $57M project in Alabama'],
#  ['FDX',
#   'Nov-17-21',
#   '04:09PM',
#   'FedEx opens facility in West Valley, looks to hire more employees for the holidays'],
#  ['FDX',
#   'Nov-17-21',
#   '11:00AM',
#   'Waymo, UPS expand autonomous freight truck tie-up ahead of holidays'],
#  ['FDX',
#   'Nov-17-21',
#   '10:48AM',
#   'Europe is the only region where COVID-19 deaths rose in the latest week, as U.S. embarks on effort to greatly boost vaccine manufacturing'],
#  ['FDX',
#   'Nov-17-21',
#   '10:25AM',
#   'Supply chains will get a little better in December and then tight again in January: Analyst'],
#  ['FDX',
#   'Nov-16-21',
#   '05:41PM',
#   'Without Violence, Solana and Other Cryptos Cant Stick'],
#  ['FDX',
#   'Nov-16-21',
#   '03:03PM',
#   "Trucker shortage: There are almost '400,000 self-employed truckers,' Convoy research director says"],
#  ['FDX',
#   'Nov-16-21',
#   '02:13PM',
#   'Wait for More Information on XYO Before Buying It'],
#  ['FDX',
#   'Nov-16-21',
#   '10:33AM',
#   '5 Reasons UPS Deserves to Be at an All-Time High'],
#  ['FDX',
#   'Nov-15-21',
#   '05:45PM',
#   'FedEx (FDX) Stock Moves -0.62%: What You Should Know'],
#  ['FDX',
#   'Nov-15-21',
#   '12:08PM',
#   'Heres Why FedEx (FDX) Became Longleaf Partners Largest Q3 Detractor'],
#  ['FDX',
#   'Nov-15-21',
#   '07:39AM',
#   "CNBC's Final Trades: Visa, FedEx, Nordstrom And This Auto Major That's Valued Better Than Peers"],
#  ['FDX', 'Nov-15-21', '07:32AM', 'This Chart Shows a Defining Moment for UPS'],
#  ['FDX',
#   'Nov-13-21',
#   '04:02PM',
#   'Top 10 Stock Picks of Adam Usdans Trellus Management'],
#  ['FDX',
#   'Nov-13-21',
#   '09:33AM',
#   'UPDATE 1-Boeing says in advanced talks to sell 777X freighters'],
#  ['FDX',
#   'Nov-12-21',
#   '02:35PM',
#   'Port of Baltimore taking on new ships amid global supply chain mess'],
#  ['FDX',
#   'Nov-12-21',
#   '02:16PM',
#   'The Social Contract Is Being Shredded. Investors Should Worry.'],
#  ['FDX',
#   'Nov-12-21',
#   '10:20AM',
#   '2 Top Value Stocks With Huge Dividend Growth Potential'],
#  ['FDX',
#   'Nov-11-21',
#   '01:41PM',
#   'Why this cute robot could soon deliver your next burrito'],
#  ['FDX',
#   'Nov-11-21',
#   '10:01AM',
#   "Saluting Marvin Hill's Continued Service to the Military Community on Veterans Day"],
#  ['FDX',
#   'Nov-11-21',
#   '06:26AM',
#   'Returns On Capital At FedEx (NYSE:FDX) Have Stalled'],
#  ['FDX', 'Nov-10-21', '07:30AM', 'UPS Silences the Doubters'],
#  ['FDX',
#   'Nov-10-21',
#   '06:20AM',
#   'Should You Invest in the iShares U.S. Transportation ETF (IYT)?'],
#  ['FDX',
#   'Nov-09-21',
#   '07:02PM',
#   'Biden Spoke With CEOs of Walmart, UPS, FedEx, Target on Supply Chains, White House Says'],
#  ['FDX',
#   'Nov-09-21',
#   '05:45PM',
#   'FedEx (FDX) Gains As Market Dips: What You Should Know'],
#  ['FDX',
#   'Nov-09-21',
#   '04:18PM',
#   'Biden spoke with CEOs of Walmart, UPS, FedEx, Target on supply chains, White House says'],
#  ['FDX',
#   'Nov-09-21',
#   '04:05PM',
#   'UPDATE 4-Biden talks to Walmart, UPS, Target, other CEOs on supply issues'],
#  ['FDX',
#   'Nov-09-21',
#   '03:46PM',
#   'Biden talks to Walmart, UPS, Target, other CEOs on supply issues']]

# %%
# Instantiate the sentiment intensity analyzer
vader = SentimentIntensityAnalyzer()

# Set column names
columns = ['ticker', 'date', 'time', 'headline']

# Convert the parsed_news list into a DataFrame called 'parsed_and_scored_news'
parsed_and_scored_news = pd.DataFrame(parsed_news, columns=columns)

# Iterate through the headlines and get the polarity scores using vader
scores = parsed_and_scored_news['headline'].apply(vader.polarity_scores).tolist()

# Convert the 'scores' list of dicts into a DataFrame
scores_df = pd.DataFrame(scores)

# Join the DataFrames of the news and the list of dicts
parsed_and_scored_news = parsed_and_scored_news.join(scores_df, rsuffix='_right')

# Convert the date column from string to datetime
parsed_and_scored_news['date'] = pd.to_datetime(parsed_and_scored_news.date).dt.date

parsed_and_scored_news.head()
# Out:
#   ticker        date     time  ...    neu    pos  compound
# 0   ADBE  2021-12-16  09:22AM  ...  1.000  0.000    0.0000
# 1   ADBE  2021-12-16  09:18AM  ...  0.894  0.000   -0.2263
# 2   ADBE  2021-12-16  09:01AM  ...  1.000  0.000    0.0000
# 3   ADBE  2021-12-16  08:22AM  ...  0.561  0.206   -0.0772
# 4   ADBE  2021-12-16  08:05AM  ...  0.852  0.148    0.3818
#
# [5 rows x 8 columns]

# %%
plt.rcParams['figure.figsize'] = [30, 6]

# Group by date and ticker columns from scored_news and calculate the mean
mean_scores = parsed_and_scored_news.groupby(['ticker','date']).mean()

# Unstack the column ticker
mean_scores = mean_scores.unstack()

# Get the cross-section of compound in the 'columns' axis
mean_scores = mean_scores.xs('compound', axis="columns").transpose()

# Plot a bar chart with pandas
mean_scores.plot(kind = 'bar')
plt.grid()
